# %%
import sys 
sys.path.append('..')
from utils.utils import load_dataframes, load_dataframe, write_df_to_csv, write_list_to_csv
from utils.paths import HASHTAG_FREQUENCY_DIR, HASHTAGS_PER_USER_DIR, GREEDY_MODULARITY_DIR, make_dirs
import pandas as pd
import networkx as nx
from network.network import generate_graph_communities, draw_graph, generate_graph_communities_users
from frequency.frequency import count_hashtag_frequency, group_by_user
import os
from networkx.algorithms.community import greedy_modularity_communities

make_dirs()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/sophiaknapp/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/sophiaknapp/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
n_users = 100
n_hashtags = 500
# quarter = 'city'
quarter = 'schwabing'

quarter = 'neuperlach'
df = load_dataframe(HASHTAGS_PER_USER_DIR, quarter)
df_frequency = load_dataframe(HASHTAG_FREQUENCY_DIR, quarter)

file_name = quarter + '_' + str(n_users) + 'users_'

forbidden_hashtags = [quarter, 'münchen', 'munich', 'muc', 'mu', 'bayern', 'bavaria', 'muenchen', 'minga', 'germany', 'deutschland', '089', '089münchen']
G = generate_graph_communities_users(df_frequency, df, n_users, n_hashtags, forbidden_hashtags)

communities = greedy_modularity_communities(G, weight='weight', resolution=1.6)

for community in communities:
    # info for cluster: total users involved
    for user in community:
        hashtags = G.nodes[user]['hashtags']
        print(hashtags)
    print(sorted(community))
# Out:
# >> now loading: neuperlach
# >> now loading: neuperlach
# /Users/sophiaknapp/instagrammining/hashtags/network/network.py:128: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['hashtags'] = df['hashtags'].apply(lambda x: [hashtag for hashtag in x if hashtag in most_common_hashtags and not hashtag in forbidden_hashtags])
# ['haidhausen', 'trudering', 'perlach', 'taufkirchen', 'waldperlach', 'laim', 'haar', 'sauerlach', 'maxvorstadt', 'starnberg', 'giesing', 'moosach', 'isar', 'ottobrunn', 'freising', 'unterhaching', 'solln', 'unterföhring', 'oberhaching', 'bmw', 'lifestyle', 'brunnthal', 'hohenbrunn', 'schwabing', 'sendling', 'grünwald', 'lehel', 'putzbrunn', 'neubiberg', 'erding', 'berge', 'urlaub', 'rosenheim', 'höhenkirchen']
# ...
