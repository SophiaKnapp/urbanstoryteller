# %%
import sys 
sys.path.append('..')
from utils.paths import make_dirs, QUARTERS_DICT, HASHTAGS_PER_USER_DIR, HASHTAG_FREQUENCY_DIR, HASHTAG_FREQUENCY_DIR_ALL, HASHTAG_TOP_DIR
from utils.utils import load_dataframes, load_dataframe, write_dict_to_csv, write_list_to_csv, write_df_to_csv
import pandas as pd
import os
from nltk.probability import FreqDist
import numpy as np
import math

make_dirs()

min_count = 10

# %%
def group_by_user(df):
    df = df.groupby('owner_id').agg(
        hashtags=pd.NamedAgg(column='hashtags', aggfunc='sum'), 
        post_count=pd.NamedAgg(column='shortcode', aggfunc='count'),
    )
    df = df.sort_values(by=['post_count'], ascending=False)
    df['hashtags'] = df['hashtags'].apply(lambda x: list(set(x)))
    return df

# %%
def count_hashtag_frequency(df):
    hashtags = list(df['hashtags'])
    flat_list = [item.lower() for sublist in hashtags for item in sublist]    
    fdist = FreqDist(flat_list)
    return fdist.most_common()

# %% [markdown]
# ## Count hashtags in every district
# - Group hashtags by user in order to give every user one "vote" per hashtag
# - count absolute and relative amount
# - drop hashtags that are mentioned by less than [min_count] people

# %%
dict = QUARTERS_DICT()
for quarter in dict:
    print('>> now processing', quarter)
    df = dict[quarter]
    df = group_by_user(df)
    write_df_to_csv(df, quarter, HASHTAGS_PER_USER_DIR)
    fdist = count_hashtag_frequency(df)
    df = pd.DataFrame(fdist, columns=['hashtag', 'count'])
    df.drop(df[df['count'] < min_count].index, inplace = True)
    count_quarter = df.iloc[0]['count']
    df['relative_amount'] = df['count'] / count_quarter
    write_df_to_csv(df, quarter, HASHTAG_FREQUENCY_DIR)
# Out:
# >> now loading: allach
# >> now loading: altperlach
# >> now loading: altstadt
# >> now loading: amhart
# >> now loading: arabellapark
# >> now loading: au
# >> now loading: aubing
# >> now loading: bergamlaim
# >> now loading: bogenhausen
# >> now loading: borstei
# >> now loading: daglfing
# >> now loading: denning
# >> now loading: fasanerie
# >> now loading: fasangarten
# >> now loading: feldmoching
# >> now loading: forstenried
# >> now loading: freiham
# >> now loading: freimann
# >> now loading: fröttmaning
# >> now loading: fürstenried
# >> now loading: giesing
# >> now loading: hadern
# >> now loading: haidhausen
# >> now loading: harlaching
# >> now loading: harras
# >> now loading: harthof
# >> now loading: hasenbergl
# >> now loading: hellabrunn
# >> now loading: herzogpark
# >> now loading: isarvorstadt
# >> now loading: johanneskirchen
# >> now loading: kieferngarten
# >> now loading: kirchtrudering
# >> now loading: laim
# >> now loading: lehel
# >> now loading: lerchenau
# >> now loading: lochhausen
# >> now loading: ludwigsvorstadt
# >> now loading: maxvorstadt
# >> now loading: messestadtriem
# >> now loading: milbertshofen
# >> now loading: mittersendling
# >> now loading: moosach
# >> now loading: neuaubing
# >> now loading: neubiberg
# >> now loading: neuhausen
# >> now loading: neuperlach
# >> now loading: nymphenburg
# >> now loading: oberföhring
# >> now loading: obermenzing
# >> now loading: obersendling
# >> now loading: olympiadorf
# >> now loading: pasing
# >> now loading: ramersdorf
# >> now loading: riem
# >> now loading: schwabing
# >> now loading: sendling
# >> now loading: solln
# >> now loading: studentenstadt
# >> now loading: thalkirchen
# >> now loading: trudering
# >> now loading: untermenzing
# >> now loading: waldtrudering
# >> now loading: werksviertel
# >> now loading: westend
# >> now loading: zamdorf
# >> now processing allach
# 31527
# >> now processing altperlach
# 5426
# >> now processing altstadt
# 17224
# >> now processing amhart
# 4049
# >> now processing arabellapark
# 11198
# >> now processing au
# 20971
# >> now processing aubing
# 39564
# >> now processing bergamlaim
# 26451
# >> now processing bogenhausen
# 119693
# >> now processing borstei
# 8004
# >> now processing daglfing
# 7051
# >> now processing denning
# 2529
# >> now processing fasanerie
# 6621
# >> now processing fasangarten
# 3424
# >> now processing feldmoching
# 22735
# >> now processing forstenried
# 13529
# >> now processing freiham
# 16284
# >> now processing freimann
# 16665
# >> now processing fröttmaning
# 17047
# >> now processing fürstenried
# 8163
# >> now processing giesing
# 206159
# >> now processing hadern
# 20264
# >> now processing haidhausen
# 101025
# >> now processing harlaching
# 40117
# >> now processing harras
# 11229
# >> now processing harthof
# 3504
# >> now processing hasenbergl
# 11171
# >> now processing hellabrunn
# 76233
# >> now processing herzogpark
# 6033
# >> now processing isarvorstadt
# 39238
# >> now processing johanneskirchen
# 5448
# >> now processing kieferngarten
# 2052
# >> now processing kirchtrudering
# 515
# >> now processing laim
# 49342
# >> now processing lehel
# 73595
# >> now processing lerchenau
# 3516
# >> now processing lochhausen
# 12120
# >> now processing ludwigsvorstadt
# 10650
# >> now processing maxvorstadt
# 251468
# >> now processing messestadtriem
# 3170
# >> now processing milbertshofen
# 17800
# >> now processing mittersendling
# 1831
# >> now processing moosach
# 61851
# >> now processing neuaubing
# 11237
# >> now processing neubiberg
# 31011
# >> now processing neuhausen
# 98768
# >> now processing neuperlach
# 36600
# >> now processing nymphenburg
# 438410
# >> now processing oberföhring
# 9801
# >> now processing obermenzing
# 33126
# >> now processing obersendling
# 22305
# >> now processing olympiadorf
# 19963
# >> now processing pasing
# 63308
# >> now processing ramersdorf
# 10759
# >> now processing riem
# 39751
# >> now processing schwabing
# 295717
# >> now processing sendling
# 124701
# >> now processing solln
# 53628
# >> now processing studentenstadt
# 5253
# >> now processing thalkirchen
# 46100
# >> now processing trudering
# 50969
# >> now processing untermenzing
# 12493
# >> now processing waldtrudering
# 7126
# >> now processing werksviertel
# 71670
# >> now processing westend
# 7330
# >> now processing zamdorf
# 1016

# %% [markdown]
# ## Count hashtags in the whole city
# - Same as above, but for posts downloaded from all districts

# %%
df = pd.DataFrame()
dict = QUARTERS_DICT()
for quarter in dict:
    df = df.append(dict[quarter])
    print('>> now processing', quarter)


df = df.drop_duplicates(subset='post_url', keep="first")
df = group_by_user(df)
user_count = len(df)

fdist = count_hashtag_frequency(df)
df = pd.DataFrame(fdist, columns=['hashtag', 'count'])
df.drop(df[df['count'] < min_count].index, inplace = True)
df['relative_amount'] = df['count'] / user_count

write_df_to_csv(df,'count_all_quarters', HASHTAG_FREQUENCY_DIR_ALL)
# Out:
# >> now loading: allach
# >> now loading: altperlach
# >> now loading: altstadt
# >> now loading: amhart
# >> now loading: arabellapark
# >> now loading: au
# >> now loading: aubing
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/6c/_dzq3mkj1pn46mx5cn0zmsg00000gn/T/ipykernel_20522/4261671855.py in <module>
#       1 df = pd.DataFrame()
# ----> 2 dict = QUARTERS_DICT()
#       3 for quarter in dict:
#       4     df = df.append(dict[quarter])
#       5     print('>> now processing', quarter)
#
# ~/urbanstoryteller/data processing (python)/utils/paths.py in QUARTERS_DICT(n)
#      92     for quarter in potatoes:
#      93         print ('>> now loading:', quarter)
# ---> 94         quarters[quarter] = QUARTER_CLEANED_RESULTS(quarter)
#      95     return quarters
#      96
#
# ~/urbanstoryteller/data processing (python)/utils/paths.py in QUARTER_CLEANED_RESULTS(quarter)
#      70 def QUARTER_CLEANED_RESULTS(quarter):
#      71     path = os.path.join(POTATOES_CLEANED_DIR, quarter + '.csv')
# ---> 72     return read_result_csv(path)
#      73
#      74 # def QUARTERS_DICT_RAW(n=-1):
#
# ~/urbanstoryteller/data processing (python)/utils/utils.py in read_result_csv(path)
#      46
#      47 def read_result_csv(path):
# ---> 48   df = pd.read_csv(path, header=0)
#      49   if 'hashtags' in df.columns:
#      50     df['hashtags'] = df['hashtags'].map(get_literals)
#
# /usr/local/lib/python3.8/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# /usr/local/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     452
#     453     try:
# --> 454         data = parser.read(nrows)
#     455     finally:
#     456         parser.close()
#
# /usr/local/lib/python3.8/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1131     def read(self, nrows=None):
#    1132         nrows = _validate_integer("nrows", nrows)
# -> 1133         ret = self._engine.read(nrows)
#    1134
#    1135         # May alter columns / col_dict
#
# /usr/local/lib/python3.8/site-packages/pandas/io/parsers.py in read(self, nrows)
#    2035     def read(self, nrows=None):
#    2036         try:
# -> 2037             data = self._reader.read(nrows)
#    2038         except StopIteration:
#    2039             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# /usr/local/lib/python3.8/site-packages/pandas/core/dtypes/common.py in is_categorical_dtype(arr_or_dtype)
#     540
#     541
# --> 542 def is_categorical_dtype(arr_or_dtype) -> bool:
#     543     """
#     544     Check whether an array-like or dtype is of the Categorical dtype.
#
# KeyboardInterrupt:

# %% [markdown]
# ## Calculate uniqueness and rank of hashtags for every district
# - uniqueness as ratio between relative amount of a hashtag in a district and in the whole city
# - rank as amount * uniqueness^2 , as only uniqeness results in obscure hashtags

# %%
def get_uniqueness(dfs, df_all, out_dir):
    idx = 1

    for quarter in dfs:
        print ('file no:', idx)
        idx += 1
        print ('>> now processing:', quarter)
        df = dfs[quarter]
        df.set_index('hashtag')

        df = df.join(df_all.set_index('hashtag'), on='hashtag', lsuffix='_quarter', rsuffix='_city')
        df['uniqueness'] = df['relative_amount_quarter'] / df['relative_amount_city']
        df['rank'] = df['count_quarter'] * df['uniqueness'] * df['uniqueness']
        df.sort_values(by=['rank'], ascending=False, inplace=True)
        write_df_to_csv(df, quarter, out_dir)
    return

# %%
dfs = load_dataframes(HASHTAG_FREQUENCY_DIR)
df_all = load_dataframe(HASHTAG_FREQUENCY_DIR_ALL, 'count_all_quarters')

get_uniqueness(dfs, df_all, HASHTAG_TOP_DIR)
# Out:
# >> now loading: allach
# >> now loading: altperlach
# >> now loading: altstadt
# >> now loading: amhart
# >> now loading: arabellapark
# >> now loading: au
# >> now loading: aubing
# >> now loading: bergamlaim
# >> now loading: bogenhausen
# >> now loading: borstei
# >> now loading: daglfing
# >> now loading: denning
# >> now loading: fasanerie
# >> now loading: fasangarten
# >> now loading: feldmoching
# >> now loading: forstenried
# >> now loading: freiham
# >> now loading: freimann
# >> now loading: fröttmaning
# >> now loading: fürstenried
# >> now loading: giesing
# >> now loading: hadern
# >> now loading: haidhausen
# >> now loading: harlaching
# >> now loading: harras
# >> now loading: harthof
# >> now loading: hasenbergl
# >> now loading: hellabrunn
# >> now loading: herzogpark
# >> now loading: isarvorstadt
# >> now loading: johanneskirchen
# >> now loading: kieferngarten
# >> now loading: kirchtrudering
# >> now loading: laim
# >> now loading: lehel
# >> now loading: lerchenau
# >> now loading: lochhausen
# >> now loading: ludwigsvorstadt
# >> now loading: maxvorstadt
# >> now loading: messestadtriem
# >> now loading: milbertshofen
# >> now loading: mittersendling
# >> now loading: moosach
# >> now loading: neuaubing
# >> now loading: neubiberg
# >> now loading: neuhausen
# >> now loading: neuperlach
# >> now loading: nymphenburg
# >> now loading: oberföhring
# >> now loading: obermenzing
# >> now loading: obersendling
# >> now loading: olympiadorf
# >> now loading: pasing
# >> now loading: ramersdorf
# >> now loading: riem
# >> now loading: schwabing
# >> now loading: sendling
# >> now loading: solln
# >> now loading: studentenstadt
# >> now loading: thalkirchen
# >> now loading: trudering
# >> now loading: untermenzing
# >> now loading: waldtrudering
# >> now loading: werksviertel
# >> now loading: westend
# >> now loading: zamdorf
# >> now loading: count_all_quarters
# file no: 1
# >> now processing: allach
# file no: 2
# >> now processing: altperlach
# file no: 3
# >> now processing: altstadt
# file no: 4
# >> now processing: amhart
# file no: 5
# >> now processing: arabellapark
# file no: 6
# >> now processing: au
# file no: 7
# >> now processing: aubing
# file no: 8
# >> now processing: bergamlaim
# file no: 9
# >> now processing: bogenhausen
# file no: 10
# >> now processing: borstei
# file no: 11
# >> now processing: daglfing
# file no: 12
# >> now processing: denning
# file no: 13
# >> now processing: fasanerie
# file no: 14
# >> now processing: fasangarten
# file no: 15
# >> now processing: feldmoching
# file no: 16
# >> now processing: forstenried
# file no: 17
# >> now processing: freiham
# file no: 18
# >> now processing: freimann
# file no: 19
# >> now processing: fröttmaning
# file no: 20
# >> now processing: fürstenried
# file no: 21
# >> now processing: giesing
# file no: 22
# >> now processing: hadern
# file no: 23
# >> now processing: haidhausen
# file no: 24
# >> now processing: harlaching
# file no: 25
# >> now processing: harras
# file no: 26
# >> now processing: harthof
# file no: 27
# >> now processing: hasenbergl
# file no: 28
# >> now processing: hellabrunn
# file no: 29
# >> now processing: herzogpark
# file no: 30
# >> now processing: isarvorstadt
# file no: 31
# >> now processing: johanneskirchen
# file no: 32
# >> now processing: kieferngarten
# file no: 33
# >> now processing: kirchtrudering
# file no: 34
# >> now processing: laim
# file no: 35
# >> now processing: lehel
# file no: 36
# >> now processing: lerchenau
# file no: 37
# >> now processing: lochhausen
# file no: 38
# >> now processing: ludwigsvorstadt
# file no: 39
# >> now processing: maxvorstadt
# file no: 40
# >> now processing: messestadtriem
# file no: 41
# >> now processing: milbertshofen
# file no: 42
# >> now processing: mittersendling
# file no: 43
# >> now processing: moosach
# file no: 44
# >> now processing: neuaubing
# file no: 45
# >> now processing: neubiberg
# file no: 46
# >> now processing: neuhausen
# file no: 47
# >> now processing: neuperlach
# file no: 48
# >> now processing: nymphenburg
# file no: 49
# >> now processing: oberföhring
# file no: 50
# >> now processing: obermenzing
# file no: 51
# >> now processing: obersendling
# file no: 52
# >> now processing: olympiadorf
# file no: 53
# >> now processing: pasing
# file no: 54
# >> now processing: ramersdorf
# file no: 55
# >> now processing: riem
# file no: 56
# >> now processing: schwabing
# file no: 57
# >> now processing: sendling
# file no: 58
# >> now processing: solln
# file no: 59
# >> now processing: studentenstadt
# file no: 60
# >> now processing: thalkirchen
# file no: 61
# >> now processing: trudering
# file no: 62
# >> now processing: untermenzing
# file no: 63
# >> now processing: waldtrudering
# file no: 64
# >> now processing: werksviertel
# file no: 65
# >> now processing: westend
# file no: 66
# >> now processing: zamdorf
